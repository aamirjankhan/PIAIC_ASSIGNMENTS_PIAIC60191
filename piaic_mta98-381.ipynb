# %%
import pandas as pd

# %%
import re
df = open("data_piaic.txt","r").read()
df = df.split('\n')
df
# Out:
# ['House no 846, Street 04, Mustufa Taj colony, Korangi 3-1/2',
#  'House# 846/2, Block 49, Samanabad',
#  'House# 12, Street# 2, Sector B, DHA 2 Islamabad',
#  'House No 7110, Street 1-B, Naseerabad Peshawar Road Rawalpindi',
#  'House #42A mohallah hafizabad dhoke hassu Westrige 2',
#  'Blue Area , Islamabad',
#  'Mir Munzil House#4 Ward#6',
#  'Street 104,  House 78/5-A, Sector G-7/4 Islamabad ',
#  '918-PD St# 8, Abassiabad, Ali Akbar Market, Pandora, Rawalpindi',
#  'House# SA-792-A, Street# 2, Ghazali road Sadiqabad Rawalpindi',
#  'House 460 street 4 Model Town Humak Islamabad',
#  'St 03 Kalyamabad Westridge Rwp Cantt',
#  'House 88 street 81 sector E-11/2 Islamabad',
#  'Kho Baba Jalal Din Wala Village Bahmni Wala City And District Kasur ',
#  'House#04, Street#01, Azmat town, Dhoke Jilani Barakahu, Islamabad',
#  'House No 1115 Street 1 Block C O-9 National Police Foundation Islamabad',
#  'H.no: 725 , Street: 52 , Sector : I-10/1 Islamabad',
# ...
